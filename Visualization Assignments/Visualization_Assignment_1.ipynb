# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline

# %%
iris = pd.read_csv('datasets/Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
sns.set_style("ticks")
plt.figure(figsize=(14,6))
j = sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=iris,joint_kws=dict(s=50),marginal_kws={'hist_kws': {'edgecolor': 'none'}}) 
j.annotate(stats.pearsonr) # to annotate the plot in pearson's coefficient
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# sns.set_style("ticks") = To display ticks grid, <br> joint_kws for the entire pairplot -> send argument as dict, <br> marginal_kws for the type of margin plot type and styling it.

# %%
sns.set_style("ticks") #to show the extra structure(ticks) near the numbers in the axes
plt.figure(figsize=(6,i6))
sns.scatterplot(x=iris.SepalLengthCm, y=iris.SepalWidthCm,hue=iris.Species,s= 75)
plt.legend(bbox_to_anchor=(1, 0.6)) #to show the legend outside the plot
sns.despine() #to remove the 4 sided borders and convert to normal left, bottom axes

# %%
sns.boxplot(x=iris.Species,y=iris.PetalLengthCm)

# %%
sns.stripplot(x=iris.Species,y=iris.SepalLengthCm,jitter= 0.13)

# %%
#combine 2 plots
sns.boxplot(x=iris.Species,y=iris.SepalLengthCm)
sns.stripplot(x=iris.Species,y=iris.SepalLengthCm,jitter= 0.13)

# %%
sns.violinplot(x=iris.Species,y=iris.SepalLengthCm)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
pp = sns.pairplot(data=iris,vars=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'],diag_kws = {'edgecolor':'none'},aspect =1.1)
#vars what all values from the df to plot in the pair plot

# %%
pp= sns.pairplot(data=iris,vars=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'],hue='Species',diag_kind='hist',diag_kws = {'edgecolor':'none','bins':8},aspect =1)

# %% [markdown]
# vars what all values from the df to plot in the pair plot <br>
# diag_kind -> which type of plots for the diagonal ones<br>
# diag_kws -> diagonal plot properties : edgecolor of the bars, no of bins

# %%
iris_new = iris.iloc[1:,1:-1]
sns.heatmap(iris_new.corr(),annot =True,cmap= 'summer')
plt.xticks(rotation=0,fontsize ='9')
# Out:
# (array([0.5, 1.5, 2.5, 3.5]), <a list of 4 Text xticklabel objects>)

# %% [markdown]
# Heatmap : Used to form heatmap of NUMERIC value only. Filling type -> correlation, annot = True to display values in the boxes.plt.xticks(rotation=0) to horizontally align the x labels.

# %%
iris.hist(column=["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm", "Species"],figsize=(10,5),edgecolor='black')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000167476D8CF8>,
# ...
#       dtype=object)

# %%
colors = ['blue',"medium green","pale red"]
sns.swarmplot(x=iris["Species"],y=iris['PetalLengthCm'],palette = sns.xkcd_palette(colors))
plt.grid(axis= 'y')

# %% [markdown]
# To create a custom color map using xkcd_palette function which accepts general naming of colors rather than RGB or hex colors
